# %%
import pandas as pd

# %%
import pandas as pd 

# 윈도우 환경에서 파일을 그대로 읽으면 유니코드 에러 발생, encoding을 CP949로 강제 지정해준다
data = pd.read_csv('Input/DFE_project_data_raw.csv')
# data = pd.read_csv('C:\WorkingArea\Final_Project\Input\shc_sample.csv', encoding='CP949')

# %%
data.head(3)
# Out:
#       회사이름   회사코드     리뷰코드       직종구분 재직상태 근무지역        등록일자  별점평가  승진기회  복지급여  \
# 0  삼성전자(주)  30139  1084668  경영/기획/컨설팅  전직원   해외  2019-04-18    80    80    80
# 1  삼성전자(주)  30139  1084223  생산관리/품질관리  전직원   경기  2019-04-18    80    60   100
# 2  삼성전자(주)  30139  1083148      인사/총무  전직원   경기  2019-04-17    80    20   100
#
#    워라밸  사내문화  경영진                                               기업장점  \
# 0   60    60   80  연봉과 복리후생이 매우 좋으며 열심히 하면(운도 필요하지만) 기회가 주어지는 곳. ...
# 1   80    80   80              글로벌 1위기업답게 체계적인 시스템으로 돌아가는 조직문화와 업무진행
# 2  100    80   80    아침 점심 저녁 다 제공, 셔틀버스도 운영되고 근무환경 좋음급여가 하는일에 비해 많음
#
#                                                 기업단점  \
# 0  조직이 방대하여 의사결정이 느리고 소통이 잘 되지 않음. 보신주의, 상명하복, 줄서...
# 1             굉장히 전문적이라서 본인의 업무외엔 전혀 모름다양하게 배우기는 어려움
# 2                    사업부 내에 자주 조직이 변경되어 맡는 팀들이 자주 바뀜
#
#                                                 바라는점 성장예상           추천여부
# 0  단기 성과주의를 경계해야 함. 최고경영진은 장기비전과 미래를 고민하나 적지 않은 수...   비슷  이 기업을 추천 합니다!
# ...

# %%
df_train = data.loc[(data['회사이름']=='코리안리재보험(주)'),:]

# %%
df_train.head(3)
# Out:
#               회사이름  회사코드     리뷰코드      직종구분 재직상태 근무지역        등록일자  별점평가  승진기회  \
# 387455  코리안리재보험(주)  7278  1048909     영업/제휴  전직원   서울  2019-03-30    80    60
# 387456  코리안리재보험(주)  7278   947083     금융/재무  전직원   서울  2019-01-11   100    60
# 387457  코리안리재보험(주)  7278   889649  마케팅/시장조사  현직원   서울  2018-11-18    80    60
#
#         복지급여  워라밸  사내문화  경영진  \
# 387455   100   80    80   60
# 387456   100   80    80   60
# 387457   100  100    60   80
#
#                                                      기업장점  \
# 387455  충분한 복지. 괜찮은 급여. 기업문화가 군대식에서 개인주의로 많이 변하고 있음. 눈...
# 387456  한국에서 거의 독과점 시장을 형성하고 있어서 기업의 미래 전망이 괜찮음 보수도 거의...
# 387457  복지 양호, 자기개발비 지원, 주차장 주차 가능, 국내 유일 전업 재보사, 젊은 b...
#
#                                                      기업단점  \
# 387455  시스템이 구식. 윗사람들 마인드가 구식. 직원들이 너무 똑똑한걸 윗사람들이 원하지 ...
# 387456  조직의 규모가 적은 점은 별로일 수 있을 듯 만약에 조직 규모가 크다면 팀 내에 트...
# 387457  사내 정치 활발, 대리가 많음, 전문성 보다 접대 등 마케팅 중시하는 과거 기업문화...
#
# ...

# %%
temp = df_train.loc[(df_train['리뷰코드']==889649),:]

# %%
temp.head()
# Out:
#               회사이름  회사코드    리뷰코드      직종구분 재직상태 근무지역        등록일자  별점평가  승진기회  \
# 387457  코리안리재보험(주)  7278  889649  마케팅/시장조사  현직원   서울  2018-11-18    80    60
#
#         복지급여  워라밸  사내문화  경영진  \
# 387457   100  100    60   80
#
#                                                      기업장점  \
# 387457  복지 양호, 자기개발비 지원, 주차장 주차 가능, 국내 유일 전업 재보사, 젊은 b...
#
#                                                      기업단점  \
# 387457  사내 정치 활발, 대리가 많음, 전문성 보다 접대 등 마케팅 중시하는 과거 기업문화...
#
#                                                      바라는점 성장예상           추천여부
# 387457  능력있는 직원 적재 적소에 업무분장 방안 마련, 직원도 동기부여 및 자기개발이 되고...  NaN  이 기업을 추천 합니다!
